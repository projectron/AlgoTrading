# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pip install scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\sunee\appdata\roaming\python\python313\site-packages (from scipy) (2.1.2)
# Downloading scipy-1.14.1-cp313-cp313-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.5 MB 2.7 MB/s eta 0:00:17
#    - -------------------------------------- 1.8/44.5 MB 3.7 MB/s eta 0:00:12
#    -- ------------------------------------- 3.1/44.5 MB 4.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.7/44.5 MB 5.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.0/44.5 MB 5.4 MB/s eta 0:00:08
#    ------ --------------------------------- 7.6/44.5 MB 5.6 MB/s eta 0:00:07
#    -------- ------------------------------- 8.9/44.5 MB 5.7 MB/s eta 0:00:07
#    --------- ------------------------------ 10.5/44.5 MB 5.9 MB/s eta 0:00:06
#    ---------- ----------------------------- 11.8/44.5 MB 5.9 MB/s eta 0:00:06
#    ------------ --------------------------- 13.4/44.5 MB 6.0 MB/s eta 0:00:06
#    ------------- -------------------------- 14.7/44.5 MB 6.1 MB/s eta 0:00:05
#    -------------- ------------------------- 16.3/44.5 MB 6.2 MB/s eta 0:00:05
#    --------------- ------------------------ 17.6/44.5 MB 6.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 19.1/44.5 MB 6.3 MB/s eta 0:00:05
#    ------------------ --------------------- 20.4/44.5 MB 6.3 MB/s eta 0:00:04
#    ------------------- -------------------- 22.0/44.5 MB 6.3 MB/s eta 0:00:04
#    -------------------- ------------------- 23.3/44.5 MB 6.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 24.9/44.5 MB 6.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 26.2/44.5 MB 6.4 MB/s eta 0:00:03
#    ------------------------ --------------- 27.8/44.5 MB 6.4 MB/s eta 0:00:03
#    -------------------------- ------------- 29.1/44.5 MB 6.4 MB/s eta 0:00:03
#    --------------------------- ------------ 30.7/44.5 MB 6.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 32.0/44.5 MB 6.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.3/44.5 MB 6.5 MB/s eta 0:00:02
#    ------------------------------- -------- 34.9/44.5 MB 6.5 MB/s eta 0:00:02
#    -------------------------------- ------- 36.4/44.5 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 37.7/44.5 MB 6.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/44.5 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 40.9/44.5 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/44.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.14.1

# %%
mcdon = pd.read_csv('mcdonalds.csv', index_col='Date', parse_dates = True)

# %%
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon.plot().hist
# Out:
# <bound method Axes.hist of <Axes: xlabel='Date'>>

# %%
mcdon['Adj. Close'].plot() # more interpretable
# Out:
# <Axes: xlabel='Date'>

# %%
mcdon['Adj. Volume'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01', '2009-01-01'], ylim=(20,50), ls= '--', c='red')
# Out:
# <Axes: xlabel='Date'>

# %%
idx = mcdon.loc['2007-01-01':'2007-05-01'].index
idx
# Out:
# DatetimeIndex(['2007-01-03', '2007-01-04', '2007-01-05', '2007-01-08',
#                '2007-01-09', '2007-01-10', '2007-01-11', '2007-01-12',
#                '2007-01-16', '2007-01-17', '2007-01-18', '2007-01-19',
#                '2007-01-22', '2007-01-23', '2007-01-24', '2007-01-25',
#                '2007-01-26', '2007-01-29', '2007-01-30', '2007-01-31',
#                '2007-02-01', '2007-02-02', '2007-02-05', '2007-02-06',
#                '2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-20', '2007-02-21', '2007-02-22', '2007-02-23',
#                '2007-02-26', '2007-02-27', '2007-02-28', '2007-03-01',
#                '2007-03-02', '2007-03-05', '2007-03-06', '2007-03-07',
#                '2007-03-08', '2007-03-09', '2007-03-12', '2007-03-13',
#                '2007-03-14', '2007-03-15', '2007-03-16', '2007-03-19',
#                '2007-03-20', '2007-03-21', '2007-03-22', '2007-03-23',
#                '2007-03-26', '2007-03-27', '2007-03-28', '2007-03-29',
#                '2007-03-30', '2007-04-02', '2007-04-03', '2007-04-04',
#                '2007-04-05', '2007-04-09', '2007-04-10', '2007-04-11',
#                '2007-04-12', '2007-04-13', '2007-04-16', '2007-04-17',
#                '2007-04-18', '2007-04-19', '2007-04-20', '2007-04-23',
#                '2007-04-24', '2007-04-25', '2007-04-26', '2007-04-27',
#                '2007-04-30', '2007-05-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
stock = mcdon.loc['2007-01-01':'2007-05-01']['Adj. Close']

# %%
stock
# Out:
# Date
# 2007-01-03    31.662754
# 2007-01-04    31.424580
# 2007-01-05    31.424580
# 2007-01-08    31.547276
# 2007-01-09    31.605015
#                 ...
# 2007-04-25    35.098239
# 2007-04-26    35.531283
# 2007-04-27    35.329196
# 2007-04-30    34.845630
# 2007-05-01    35.466327
# Name: Adj. Close, Length: 82, dtype: float64

# %%
fig,ax=plt.subplots()
fig.autofmt_xdate()

ax.yaxis.grid(True)
ax.xaxis.grid(True)

ax.plot(idx,stock, ls=':',c='r')
